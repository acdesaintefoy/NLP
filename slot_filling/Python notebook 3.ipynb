# %% [markdown]
# # Challenge slot-filling
# <hr style="border-width:2px;border-color:#A93226">

# %% [markdown]
# ## Introduction
#
# >
# The problem of this challenge is to determine the way a word has one meaning or another.
#     For instance after "Are you ..." in my every-day conversations I can often find feelings such as "fine", "sad", "hungry"or "happy".
#     Sometimes we hear a conversation and we miss a single word, then by knowing the words before and after (and frequently a noise that sounds like the missing word) we manage to reconstitute the whole sentence.
#     I decide to make the algorithm on the same process. The algorithm looks one after the other words in the query and find a probability vectors for the different meanings by taking in account the words around.
#
#
# - Create an alternative data base
# - Data reshaping to increase the amount of data
# - Data cleaning with nlp processes
# - Analysis of the data base to avoid important stop words
# - Probability model
# - Error Analysis
# - Conclusion and ideas to improve performance

# %% [markdown]
# ## <span style="text-decoration : underline">Import packages and datas<span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import json
from pprint import pprint
import nltk
nltk.download('punkt')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud, STOPWORDS

import sys
print ('\n' + sys.version)
print("\n 3.6.2 (v3.6.2:5fd33b5926, Jul 16 2017, 20:11:06) \n [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]")
# Out:
# 3.6.3 (default, Oct  4 2017, 06:09:15)
# [GCC 4.2.1 Compatible Apple LLVM 9.0.0 (clang-900.0.37)]
#
#  3.6.2 (v3.6.2:5fd33b5926, Jul 16 2017, 20:11:06)
#  [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]
# [nltk_data] Downloading package punkt to /Users/francois/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# <hr style="border-width:2px;border-color:#A93226">

# %% [markdown]
# Choose the type of the query by changing the number bellow in the range [0,6]. <br>Examples in the conclusion are made for number = 0 ie 'AddToPlaylist' type of query.

# %%
number = 0
list_of_query_type = ['AddToPlaylist','GetWeather','SearchCreativeWork' , 'BookRestaurant','PlayMusic','RateBook' ,'SearchScreeningEvent']
type_of_query = list_of_query_type[number]

data = json.load(open(type_of_query+'_queries.json'))
data_test = json.load(open(type_of_query+'_test.json'))

# %%
pprint(data_test)
# Out:
# {'AddToPlaylist': [{'data': [{'text': "I'd like to have this "},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Classical Relaxations'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Flow Español'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'playlist', 'text': 'digging now'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'entity_name',
#                               'text': 'Young at Heart'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'add this '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' by '},
#                              {'entity': 'artist', 'text': 'Too Poetic'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Piano Ballads'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add this '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'Old School Death Metal'}]},
#                    {'data': [{'text': 'I need to add '},
#                              {'entity': 'artist', 'text': 'baro ferret'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Urban Hits'},
#                              {'text': ' under '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' name'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist',
#                               'text': 'Might and Myth Power Metal'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'To the '},
#                              {'entity': 'playlist', 'text': 'travelling'},
#                              {'text': ' playlist, please add this '},
#                              {'entity': 'artist', 'text': 'David Gahan'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': '.'}]},
#                    {'data': [{'text': 'Please add some '},
#                              {'entity': 'artist', 'text': 'Pete Townshend'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist',
#                               'text': 'Fiesta Hits con Lali'}]},
#                    {'data': [{'text': "I'd like for "},
#                              {'entity': 'artist', 'text': 'Kasey Chambers'},
#                              {'text': "'s "},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to be an addition to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Chips and Salsa'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name',
#                               'text': 'Recalled to Life'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'This Is Alejandro Fernández'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name', 'text': 'nuba'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Metal Party'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'jo stafford'},
#                              {'text': ' music to the '},
#                              {'entity': 'playlist', 'text': 'workout twerkout'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Put '},
#                              {'entity': 'artist',
#                               'text': 'Jean Philippe Goncalves'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'running to rock 170 to 190 bpm'},
#                              {'text': '.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'virales de siempre'},
#                              {'text': ' by the '},
#                              {'entity': 'artist', 'text': 'cary brothers'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' gym playlist.'}]},
#                    {'data': [{'text': 'Onto '},
#                              {'entity': 'playlist_owner', 'text': "jerry's"},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Classical Moments in Movies'},
#                              {'text': ', please add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': '.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'Beyond the Valley of 1984'},
#                              {'text': ' in playlist '},
#                              {'entity': 'playlist',
#                               'text': 'Folk Music At The Gaslight Café'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Jerry Calliste, Jr'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Te quiero'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'porter wagoner'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist',
#                               'text': 'The Sleep Machine Waterscapes'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' '},
#                              {'entity': 'artist', 'text': 'mike'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Sexy as Folk'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name',
#                               'text': 'Brazilian Flag Anthem'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'Top 100 Alternative Tracks on '
#                                       'Spotify'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Andy Hunter'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Evening Commute'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Put '},
#                              {'entity': 'artist',
#                               'text': 'petar georgiev kalica'},
#                              {'text': ' onto the '},
#                              {'entity': 'playlist',
#                               'text': 'Old School Hip Hop'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Can you add '},
#                              {'entity': 'artist', 'text': 'Larry Heard'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'laundry'},
#                              {'text': ' playlist?'}]},
#                    {'data': [{'text': 'Put '},
#                              {'entity': 'artist',
#                               'text': 'Vandemataram Srinivas'},
#                              {'text': "'s "},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist', 'text': 'HipHop Hot 50'},
#                              {'text': '.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'millie corretjer'},
#                              {'text': ' to '},
#                              {'entity': 'playlist', 'text': 'the rhythm'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name', 'text': 'give us rest'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': '70s Smash Hits'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add this '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Hands Up'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': "I'd like for you to add "},
#                              {'entity': 'artist', 'text': 'bobby brown'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'enamorándose'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'artist', 'text': 'Jonathan Sprout'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'this is miranda lambert'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'ireland in the junior eurovision song '
#                                       'contest 2015'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Jazzy Dinner'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'The Sweet Suite'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'sarah slean'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist',
#                               'text': 'Mellowed Out Gaming'}]},
#                    {'data': [{'text': 'Add this '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Spanish Beat'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name',
#                               'text': 'lofty fake anagram'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist',
#                               'text': 'la mejor música de bso'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'work'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': "this is racionais mc's"}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' in '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': '\n playlist called '},
#                              {'entity': 'playlist', 'text': 'Hands Up'}]},
#                    {'data': [{'text': 'Can you put this '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' from '},
#                              {'entity': 'artist', 'text': 'Yutaka Ozaki'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'this is miles davis'},
#                              {'text': ' playlist?'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to playlist '},
#                              {'entity': 'playlist',
#                               'text': 'Cena con Amigos'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name',
#                               'text': 'The Famous Flower of Serving-Men'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'evening acoustic'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist', 'text': 'Indie Hipster'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'artist', 'text': '40 cal'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'laundry'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Perfect Concentration'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'artist', 'text': 'Matt Murphy'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Flow Español'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'A Very Cellular Song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist', 'text': 'masters of metal'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Can I put this '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'sin estrés'},
#                              {'text': ' playlist?'}]},
#                    {'data': [{'text': "I'd like to add "},
#                              {'entity': 'artist', 'text': 'jordan rudess'},
#                              {'text': ' onto the '},
#                              {'entity': 'playlist',
#                               'text': 'Divertido para niños'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'kent james'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'disney'},
#                              {'text': ' soundtrack.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' '},
#                              {'entity': 'artist', 'text': 'Adam Deibert'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Perfect Concentration'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Can you put the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' '},
#                              {'entity': 'artist',
#                               'text': 'Giovanni Giacomo Gastoldi'},
#                              {'text': ' onto the '},
#                              {'entity': 'playlist', 'text': 'Chill Out Music'},
#                              {'text': ' playlist?'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'hot 50'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' '},
#                              {'entity': 'artist', 'text': 'Pete Murray'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'relaxing'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'drum & breaks'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'For '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'fantastic workout'},
#                              {'text': ' can you add '},
#                              {'entity': 'artist', 'text': 'sara bareilles'},
#                              {'text': '?'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'artist', 'text': 'boy george'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Emo Forever'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Ted Heath'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'road trip'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Can you add '},
#                              {'entity': 'entity_name',
#                               'text': 'last of the ghetto astronauts'},
#                              {'text': ' to the playlist called '},
#                              {'entity': 'playlist',
#                               'text': 'black sabbath the dio years'},
#                              {'text': '?'}]},
#                    {'data': [{'text': 'Add this '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'Showstopper Being Mary Jane'}]},
#                    {'data': [{'text': 'put the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' onto '},
#                              {'entity': 'playlist',
#                               'text': 'Top Latin Alternative'},
#                              {'text': '.'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Michael Wittig'},
#                              {'text': ' music to '},
#                              {'entity': 'playlist', 'text': 'Country Icon'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'Highway Patrolman'},
#                              {'text': ' in '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist',
#                               'text': 'this is al green'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Richard McNamara'},
#                              {'text': ' newest '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Just Smile'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Annesley Malewana'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to playlist '},
#                              {'entity': 'playlist', 'text': 'indietronic'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'dishwashing'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add this '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist', 'text': 'fairy tales'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'Muzika za decu'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Crash Course'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'artist', 'text': 'derek watkins'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'This Is Johnny Cash'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'entity_name',
#                               'text': 'our little corner of the world music '
#                                       'from gilmore girls'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'The Funny Thing About Football Is'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add the current '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'This Is Tchaikovsky'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Put '},
#                              {'entity': 'artist', 'text': 'abe laboriel'},
#                              {'text': ' onto the '},
#                              {'entity': 'playlist', 'text': 'Escapada'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name', 'text': 'abacab'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': "beryl's"},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'party on fridays'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Please add this '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' by '},
#                              {'entity': 'artist', 'text': 'Paul McGuigan'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Deep House'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'can you add the current '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Calm before the storm'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Please add '},
#                              {'entity': 'entity_name',
#                               'text': 'The image of you'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist',
#                               'text': 'Crate Diggers Anonymous'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'text': ' to '},
#                              {'entity': 'playlist', 'text': 'Jazzy Dinner'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'Hipster Soul'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add this '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Sleepify'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'jack white'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist',
#                               'text': 'This Is Shakira'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'artist', 'text': 'tommy johnson'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'The MetalSucks Playlist'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'artist', 'text': 'chris clark'},
#                              {'text': ' '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'women of the blues'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add an '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist',
#                               'text': 'Jukebox Boogie Rhythm & Blues'}]},
#                    {'data': [{'text': 'add this '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Electronic Bliss'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'I need to add to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Infinite Indie Folk'},
#                              {'text': ' list the works of '},
#                              {'entity': 'artist', 'text': 'Rahim Shah'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'martin barre'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'punk unplugged'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'artist', 'text': 'tierney sutton'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'Novedades Viernes Sudamérica'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add this '},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': "dorthy's"},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': "80's party"},
#                              {'text': ' playlist'}]},
#                    {'data': [{'entity': 'entity_name',
#                               'text': 'A Very Cellular Song'},
#                              {'text': ' needs to be added to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'masters of metal'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Toyan'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Epic Gaming'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': "Mac 'N Cheese"},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add this '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'spotlight on country 2016'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add a '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' playlist '},
#                              {'entity': 'playlist', 'text': 'madden nfl 16'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'emilie autumn'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Nação Reggae'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'artist', 'text': 'Farhad Darya'},
#                              {'text': ' songs in '},
#                              {'entity': 'playlist',
#                               'text': 'virales de siempre'}]},
#                    {'data': [{'text': 'add a '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' in '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'All Out 60s'}]},
#                    {'data': [{'text': 'add '},
#                              {'entity': 'entity_name',
#                               'text': 'we have a theme song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'House Afterwork'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'add the '},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'We Everywhere'},
#                              {'text': ' playlist'}]},
#                    {'data': [{'text': 'Add '},
#                              {'entity': 'artist', 'text': 'Roel van Velzen'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist',
#                               'text': 'party of the century'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'text': ' to the '},
#                              {'entity': 'playlist', 'text': 'political punks'},
#                              {'text': ' playlist.'}]},
#                    {'data': [{'text': 'Add the '},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'text': ' to '},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'text': ' '},
#                              {'entity': 'playlist', 'text': 'Club Hits'},
#                              {'text': ' playlist.'}]}]}

# %% [markdown]
# ## <span style="text-decoration : underline">Alternative data base<span>

# %% [markdown]
# Instead of having a small sentence that is refering to an entity, I choose to split this small sentence to associate each words of it to its entity.
# As a consequence 'What will be the weather like' and 'Will the weather be like', because they have similar words, will increase the amount of data and avoid the case of a never-seen-before sentence

# %%
#Convertir les nombres écrits en nombre
def alternative_data_base(data):
    new_data = []
    for element in data[type_of_query]:
        for key,value in element.items():
            list_temp = []
            for dico in value:
                for word in dico['text'].split(' '):
                    unite_dico = {'text' : word}
                    if 'entity' in dico.keys():
                        unite_dico['entity'] = dico['entity']
                    else :
                        unite_dico['entity'] = 'None'
                    list_temp.append(unite_dico)
        new_data.append({'data' : list_temp})
    new_data = {type_of_query : new_data}
    return(new_data)

# %%
data = alternative_data_base(data)
data_test = alternative_data_base(data_test)

# %%
pprint(data)
# Out:
# {'AddToPlaylist': [{'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'another'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Cita'},
#                              {'entity': 'playlist', 'text': 'Romántica'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'clem'},
#                              {'entity': 'artist', 'text': 'burke'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Pre-Party'},
#                              {'entity': 'playlist', 'text': 'R&B'},
#                              {'entity': 'playlist', 'text': 'Jams'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Live'},
#                              {'entity': 'entity_name', 'text': 'from'},
#                              {'entity': 'entity_name', 'text': 'Aragon'},
#                              {'entity': 'entity_name', 'text': 'Ballroom'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Trapeo'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Unite'},
#                              {'entity': 'entity_name', 'text': 'and'},
#                              {'entity': 'entity_name', 'text': 'Win'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'night'},
#                              {'entity': 'playlist', 'text': 'out'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Digster'},
#                              {'entity': 'playlist', 'text': 'Future'},
#                              {'entity': 'playlist', 'text': 'Hits'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'the'},
#                              {'entity': 'playlist', 'text': 'piano'},
#                              {'entity': 'playlist', 'text': 'bar'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Cindy'},
#                              {'entity': 'artist', 'text': 'Wilson'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Spanish'},
#                              {'entity': 'entity_name', 'text': 'Harlem'},
#                              {'entity': 'entity_name', 'text': 'Incident'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'cleaning'},
#                              {'entity': 'playlist', 'text': 'the'},
#                              {'entity': 'playlist', 'text': 'house'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'The'},
#                              {'entity': 'entity_name', 'text': 'Greyest'},
#                              {'entity': 'entity_name', 'text': 'of'},
#                              {'entity': 'entity_name', 'text': 'Blue'},
#                              {'entity': 'entity_name', 'text': 'Skies'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Indie'},
#                              {'entity': 'playlist', 'text': 'Español'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': 'name'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'kids'},
#                              {'entity': 'entity_name', 'text': 'in'},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'street'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': 'plylist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'New'},
#                              {'entity': 'playlist', 'text': 'Indie'},
#                              {'entity': 'playlist', 'text': 'Mix'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'radar'},
#                              {'entity': 'playlist', 'text': 'latino'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Tranquility'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Latin'},
#                              {'entity': 'playlist', 'text': 'Pop'},
#                              {'entity': 'playlist', 'text': 'Rising'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'd'},
#                              {'entity': 'artist', 'text': 'flame'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Dcode2016'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'fairy'},
#                              {'entity': 'playlist', 'text': 'tales'}]},
#                    {'data': [{'entity': 'None', 'text': 'I'},
#                              {'entity': 'None', 'text': 'need'},
#                              {'entity': 'None', 'text': 'another'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'New'},
#                              {'entity': 'playlist', 'text': 'Indie'},
#                              {'entity': 'playlist', 'text': 'Mix'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'i'},
#                              {'entity': 'playlist', 'text': 'love'},
#                              {'entity': 'playlist', 'text': 'my'},
#                              {'entity': 'playlist', 'text': 'neo'},
#                              {'entity': 'playlist', 'text': 'soul'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': 'name'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'national'},
#                              {'entity': 'entity_name', 'text': 'treasure'},
#                              {'entity': 'entity_name', 'text': 'book'},
#                              {'entity': 'entity_name', 'text': 'of'},
#                              {'entity': 'entity_name', 'text': 'secrets'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'fire'},
#                              {'entity': 'entity_name', 'text': 'and'},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'wind'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Digster'},
#                              {'entity': 'playlist', 'text': 'Future'},
#                              {'entity': 'playlist', 'text': 'Hits'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Caleigh'},
#                              {'entity': 'artist', 'text': 'Peters'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'women'},
#                              {'entity': 'playlist', 'text': 'of'},
#                              {'entity': 'playlist', 'text': 'country'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'list'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'children'},
#                              {'entity': 'entity_name', 'text': 'of'},
#                              {'entity': 'entity_name', 'text': 'telepathic'},
#                              {'entity': 'entity_name', 'text': 'experiences'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': 'named'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'baladas'},
#                              {'entity': 'playlist', 'text': 'románticas'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': '9th'},
#                              {'entity': 'entity_name', 'text': 'Inning'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'bossa'},
#                              {'entity': 'playlist', 'text': 'nova'},
#                              {'entity': 'playlist', 'text': 'dinner'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'I'},
#                              {'entity': 'None', 'text': 'need'},
#                              {'entity': 'None', 'text': 'another'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'legendary'},
#                              {'entity': 'playlist', 'text': 'guitar'},
#                              {'entity': 'playlist', 'text': 'solos'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Slimm'},
#                              {'entity': 'artist', 'text': 'Cutta'},
#                              {'entity': 'artist', 'text': 'Calhoun'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'this'},
#                              {'entity': 'playlist', 'text': 'is'},
#                              {'entity': 'playlist', 'text': 'prince'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Always'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': "dena's"},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Baroque'},
#                              {'entity': 'playlist', 'text': '50'},
#                              {'entity': 'playlist', 'text': 'Spotify'},
#                              {'entity': 'playlist', 'text': 'Picks'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Sleepytime'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'an'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'list'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'La'},
#                              {'entity': 'playlist', 'text': 'Mejor'},
#                              {'entity': 'playlist', 'text': 'Música'},
#                              {'entity': 'playlist', 'text': 'Dance'},
#                              {'entity': 'playlist', 'text': '2017'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Hey,'},
#                              {'entity': 'entity_name', 'text': 'Johnnie'},
#                              {'entity': 'entity_name', 'text': 'Cope,'},
#                              {'entity': 'entity_name', 'text': 'Are'},
#                              {'entity': 'entity_name', 'text': 'Ye'},
#                              {'entity': 'entity_name', 'text': 'Waking'},
#                              {'entity': 'entity_name', 'text': 'Yet'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'year'},
#                              {'entity': 'playlist', 'text': 'in'},
#                              {'entity': 'playlist', 'text': 'metal'},
#                              {'entity': 'playlist', 'text': '2016'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'psychedelic'},
#                              {'entity': 'playlist', 'text': 'rock'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Can'},
#                              {'entity': 'None', 'text': 'you'},
#                              {'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Esquivando'},
#                              {'entity': 'entity_name', 'text': 'charcos'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': 'entitled'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'the'},
#                              {'entity': 'playlist', 'text': 'piano'},
#                              {'entity': 'playlist', 'text': 'bar'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'wiktor'},
#                              {'entity': 'artist', 'text': 'coj'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Sleep'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'Incorporate'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'time'},
#                              {'entity': 'entity_name', 'text': 'warp'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'into'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'fairy'},
#                              {'entity': 'playlist', 'text': 'tales'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'MakSim'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Trad'},
#                              {'entity': 'playlist', 'text': 'Folk'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'eletro'},
#                              {'entity': 'playlist', 'text': 'br'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Dinnertime'},
#                              {'entity': 'playlist', 'text': 'Acoustics'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'list'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'monsters'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'this'},
#                              {'entity': 'playlist', 'text': 'is'},
#                              {'entity': 'playlist', 'text': 'prince'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': 'a'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Chill'},
#                              {'entity': 'playlist', 'text': 'Vibes'}]},
#                    {'data': [{'entity': 'None', 'text': 'Can'},
#                              {'entity': 'None', 'text': 'you'},
#                              {'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': 'a'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Spain'},
#                              {'entity': 'playlist', 'text': 'Top'},
#                              {'entity': 'playlist', 'text': '50'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'put'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'by'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Mike'},
#                              {'entity': 'artist', 'text': 'Tramp'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'on'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Deathcore'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'ross'},
#                              {'entity': 'artist', 'text': 'the'},
#                              {'entity': 'artist', 'text': 'boss'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': "laurie's"},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'listas'},
#                              {'entity': 'playlist', 'text': 'de'},
#                              {'entity': 'playlist', 'text': 'éxitos'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'list'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'some'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Beatmaster'},
#                              {'entity': 'artist', 'text': 'V'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'This'},
#                              {'entity': 'playlist', 'text': 'Is'},
#                              {'entity': 'playlist', 'text': 'Nicky'},
#                              {'entity': 'playlist', 'text': 'Jam'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'paulinho'},
#                              {'entity': 'artist', 'text': 'da'},
#                              {'entity': 'artist', 'text': 'viola'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Radio'},
#                              {'entity': 'playlist', 'text': 'Rock'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'song'},
#                              {'entity': 'None', 'text': 'list'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Eef'},
#                              {'entity': 'artist', 'text': 'Barzelay'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Country'},
#                              {'entity': 'playlist', 'text': 'Coffeehouse'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'queen'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Olga'},
#                              {'entity': 'artist', 'text': 'Souza'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': "virginia's"},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'femme'},
#                              {'entity': 'playlist', 'text': 'fatale'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'an'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'by'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'm'},
#                              {'entity': 'artist', 'text': 'g'},
#                              {'entity': 'artist', 'text': 'sreekumar'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'laidback'},
#                              {'entity': 'playlist', 'text': 'acoustic'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'spotify'},
#                              {'entity': 'playlist', 'text': 'orchestra'},
#                              {'entity': 'playlist', 'text': 'cello'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'I'},
#                              {'entity': 'None', 'text': 'want'},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'put'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'goldy'},
#                              {'entity': 'artist', 'text': 'mcjohn'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'on'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Rock'},
#                              {'entity': 'playlist', 'text': 'Party'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'song'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': "noreen's"},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'fresh'},
#                              {'entity': 'playlist', 'text': 'finds'},
#                              {'entity': 'playlist', 'text': 'six'},
#                              {'entity': 'playlist', 'text': 'strings'}]},
#                    {'data': [{'entity': 'None', 'text': 'A'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Shawnna'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Warm'},
#                              {'entity': 'playlist', 'text': 'Hearts'},
#                              {'entity': 'playlist', 'text': 'Feel'},
#                              {'entity': 'playlist', 'text': 'Good'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Rock'},
#                              {'entity': 'playlist', 'text': 'Save'},
#                              {'entity': 'playlist', 'text': 'The'},
#                              {'entity': 'playlist', 'text': 'Queen'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Firehouse'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'acoustic'},
#                              {'entity': 'playlist', 'text': 'soul'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'list.'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'david'},
#                              {'entity': 'artist', 'text': 'cole'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Totally'},
#                              {'entity': 'playlist', 'text': 'Stress'},
#                              {'entity': 'playlist', 'text': 'Free'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Progress'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'clásica'},
#                              {'entity': 'playlist', 'text': 'para'},
#                              {'entity': 'playlist', 'text': 'todos'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'},
#                              {'entity': 'None', 'text': ''}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'tony'},
#                              {'entity': 'artist', 'text': 'thompson'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'canta'},
#                              {'entity': 'playlist', 'text': 'en'},
#                              {'entity': 'playlist', 'text': 'la'},
#                              {'entity': 'playlist', 'text': 'ducha'},
# ...
#                              {'entity': 'None', 'text': 'onto'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': '2010'},
#                              {'entity': 'playlist', 'text': 'Decade'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'that'},
#                              {'entity': 'entity_name', 'text': 'was'},
#                              {'entity': 'entity_name', 'text': 'only'},
#                              {'entity': 'entity_name', 'text': 'yesterday'},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'last'},
#                              {'entity': 'entity_name', 'text': 'ep'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Afternoon'},
#                              {'entity': 'playlist', 'text': 'Train'},
#                              {'entity': 'playlist', 'text': 'Ride'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'I'},
#                              {'entity': 'None', 'text': 'want'},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'put'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'in'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Mellowed'},
#                              {'entity': 'playlist', 'text': 'Out'},
#                              {'entity': 'playlist', 'text': 'Gaming'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'a'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'rachael'},
#                              {'entity': 'artist', 'text': 'price'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'album'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'TODO'},
#                              {'entity': 'playlist', 'text': 'EDM'}]},
#                    {'data': [{'entity': 'None', 'text': 'Put'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Strange'},
#                              {'entity': 'entity_name', 'text': 'Days'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'onto'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Fusion'},
#                              {'entity': 'playlist', 'text': 'Fest'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': 'this'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'track'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'flamenco'},
#                              {'entity': 'playlist', 'text': 'pa'},
#                              {'entity': 'playlist', 'text': 'ti'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Philip'},
#                              {'entity': 'artist', 'text': 'Labonte'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Women'},
#                              {'entity': 'playlist', 'text': 'of'},
#                              {'entity': 'playlist', 'text': 'R&B'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Kisaki'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Family'},
#                              {'entity': 'playlist', 'text': 'Road'},
#                              {'entity': 'playlist', 'text': 'Trip'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Volver'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'pop'},
#                              {'entity': 'playlist', 'text': 'gaming'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'put'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'Ramy'},
#                              {'entity': 'artist', 'text': 'Ayach'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'on'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Latin'},
#                              {'entity': 'playlist', 'text': 'Pop'},
#                              {'entity': 'playlist', 'text': 'Rising'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': 'the'},
#                              {'entity': 'None', 'text': 'current'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'sxsw'},
#                              {'entity': 'playlist', 'text': 'latin'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'tune'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'country'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Put'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'nothing'},
#                              {'entity': 'entity_name', 'text': 'remains'},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'same'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'on'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'summer'},
#                              {'entity': 'playlist', 'text': 'music'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'flying'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'Women'},
#                              {'entity': 'playlist', 'text': 'of'},
#                              {'entity': 'playlist', 'text': 'Rock'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': "I'd"},
#                              {'entity': 'None', 'text': 'like'},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': 'put'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'Ryō'},
#                              {'entity': 'entity_name', 'text': 'Yamazaki'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'onto'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'sylvia'},
#                              {'entity': 'playlist', 'text': 'plath'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist.'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'sweets'},
#                              {'entity': 'artist', 'text': 'edison'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'relaxing'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'artist', 'text': 'ana'},
#                              {'entity': 'artist', 'text': 'carolina'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'chill'}]},
#                    {'data': [{'entity': 'None', 'text': 'Add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'entity_name', 'text': 'decade'},
#                              {'entity': 'entity_name', 'text': 'in'},
#                              {'entity': 'entity_name', 'text': 'the'},
#                              {'entity': 'entity_name', 'text': 'sun'},
#                              {'entity': 'entity_name', 'text': 'best'},
#                              {'entity': 'entity_name', 'text': 'of'},
#                              {'entity': 'entity_name', 'text': 'stereophonics'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'laundry'},
#                              {'entity': 'None', 'text': '.'}]},
#                    {'data': [{'entity': 'None', 'text': 'add'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'music_item', 'text': 'artist'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'to'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist_owner', 'text': 'my'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'playlist', 'text': 'friendesemana'},
#                              {'entity': 'None', 'text': ''},
#                              {'entity': 'None', 'text': 'playlist'}]}]}

# %% [markdown]
# ## <span style="text-decoration : underline">Data Cleaning <span>

# %% [markdown]
# I choose not to use the stop.words list in the library nltk because it removes important link words such as 'to' , 'in' ... that indicates to the algorithm the entities possible before and after.
# A new type of query could be add, and the algorithm keeps working.

# %%
common_list = ['the','a','this','another','please','.','?',',','can','you','an','me',"I'd",'I','want','wanted','would','like'] 
dico_stop_words ={'AddToPlaylist' : common_list
                  , 'GetWeather' : common_list ,'RateBook':common_list, 'PlayMusic' :common_list, 
                  'PlayMusic' : common_list, 'SearchScreeningEvent': common_list}

# %% [markdown]
# ## <span style="text-decoration : underline">Data reshaping<span>

# %%
def sum_text(vecteur_text):
    output = ''
    for word in vecteur_text:
        output = output +' '+ word
    return(output)

# %%
def data_reshape(data):
    ps = PorterStemmer()
    queries_entity = []
    future_df = []
    i = 0

    for element in data[type_of_query]:
        temp = ''
        temp_entity = []
        i+=1
        for value in element.values():
            for dico in value:
                temp_future = [i]
                temp += ps.stem(dico['text'])+' '
                temp_future.append(dico['text'].lower())
                if 'entity' in dico.keys():
                    temp_entity.append(dico['entity'])
                    temp_future.append(dico['entity'])
                else :
                    temp_future.append('None')
                if '' in temp_future:
                    temp_future.remove('')
                future_df.append(temp_future)
    
    df = pd.DataFrame(future_df, columns=['query_id','text','entity'])
    df.dropna(subset = ['text','entity'], inplace = True)
    
    #We remove here stop words specificaly for each type of query
    df = df[~df.text.isin(dico_stop_words[type_of_query])]
    
    queries = df.groupby('query_id').apply(lambda x : sum_text(x.text))
        
    return({'queries_entity': queries_entity,'df':df})

# %% [markdown]
# I create the data bases on which I train the algorithm and then test it. I decided to had the entity 'None' as a string to make a single type column and fill the empty entity variable of the words without "meaning" in the raw data base.

# %%
df = data_reshape(data)['df']
df_test = data_reshape(data_test)['df']

# %% [markdown]
# Here is the queries cleaned :

# %%
df.groupby('query_id').apply(lambda x : sum_text(x.text)).reset_index(name = 'query')
# Out:
#       query_id                                              query
# 0            1               add song to cita romántica playlist.
# 1            2   add clem burke in my playlist pre-party r&b jams
# 2            3            add live from aragon ballroom to trapeo
# 3            4                  add unite and win to my night out
# 4            5                add track to my digster future hits
# 5            6                   add piano bar to my cindy wilson
# 6            7      add spanish harlem incident to cleaning house
# 7            8   add greyest of blue skies in indie español my...
# 8            9   add name kids in street to plylist new indie mix
# 9           10                             add album radar latino
# 10          11      add tranquility to latin pop rising playlist.
# 11          12                 add d flame to dcode2016 playlist.
# 12          13                        add album to my fairy tales
# 13          14           i need artist in new indie mix playlist.
# 14          15   add to playlist i love my neo soul name natio...
# 15          16   add fire and wind to my digster future hits p...
# 16          17     add caleigh peters to my women of country list
# 17          18   add children of telepathic experiences to pla...
# 18          19    add 9th inning to my bossa nova dinner playlist
# 19          20   i need tune in my legendary guitar solos play...
# 20          21   add slimm cutta calhoun to my is prince playl...
# 21          22   add always to dena's baroque 50 spotify picks...
# 22          23                             add song to sleepytime
# 23          24    add album to my list la mejor música dance 2017
# 24          25   add hey, johnnie cope, are ye waking yet to y...
# 25          26             add album to psychedelic rock playlist
# 26          27   add esquivando charcos to my playlist entitle...
# 27          28                  add wiktor coj to sleep playlist.
# 28          29   incorporate time warp into my fairy tales pla...
# 29          30                       add maksim tune to trad folk
# ...        ...                                                ...
# 1912      1913         add tim ryan to my grime shutdown playlist
# 1913      1914     put tune onto erin's house afterwork playlist?
# 1914      1915   make addition to old enough to enjoy playlist...
# 1915      1916                       add artist to latin pop hits
# 1916      1917   play used to love her to my is animal collect...
# 1917      1918   add guy warren to my bossa nova dinner playlist.
# 1918      1919   add arthur russell to my women of disco playl...
# 1919      1920   add francesco de gregori to my classical new ...
# 1920      1921   play suus to my funny thing about football is...
# 1921      1922   add outside dream syndicate to millicent's fr...
# 1922      1923                        add tune to duetos playlist
# 1923      1924         put playa fly onto my 2010 decade playlist
# 1924      1925   add that was only yesterday last ep to my aft...
# 1925      1926             i to put artist in mellowed out gaming
# 1926      1927                add rachael price album to todo edm
# 1927      1928        put strange days onto fusion fest playlist.
# 1928      1929                     add track to my flamenco pa ti
# 1929      1930        add philip labonte to women of r&b playlist
# 1930      1931            add kisaki to family road trip playlist
# 1931      1932               add volver to my pop gaming playlist
# 1932      1933                 put ramy ayach on latin pop rising
# 1933      1934                add current artist to my sxsw latin
# 1934      1935                    add tune to my country playlist
# 1935      1936   put nothing remains same on my summer music p...
# 1936      1937            add flying to my women of rock playlist
# 1937      1938   i'd to put ryō yamazaki onto my sylvia plath ...
# 1938      1939             add sweets edison to relaxing playlist
# 1939      1940                          add ana carolina to chill
# 1940      1941   add decade in sun best of stereophonics to la...
# 1941      1942            add artist to my friendesemana playlist
#
# [1942 rows x 2 columns]

# %% [markdown]
# I create a list of all entities. It is usefull to create the column of the training dataframe

# %%
all_queries_entity = df_test.entity.unique()
list(all_queries_entity)
# Out:
# ['None', 'music_item', 'playlist_owner', 'playlist', 'entity_name', 'artist']

# %% [markdown]
# >By looking the data base, I can see that after the word "add", there are a lots of artist, entity or music_item.
# I want to apply this argument to the whole data_base and put probability of presence.

# %% [markdown]
# $\text{add_col}$ is a function that iterate on row to see what entity is before for each text element of each query

# %%
def add_col(df):
    query_id = 0
    entity_before = ''
    entity_before_list = []
    for index, row in df.iterrows():
        if row.query_id == query_id :
            entity_before_list.append(entity_before)
        else :
            entity_before = ''
            entity_before_list.append(entity_before)
            query_id = row.query_id
        entity_before = row.entity
    return(entity_before_list)

# %% [markdown]
# To know for each row what is the entity of the word after, I inverse the index of the data frame and apply the same function.
# Then reinverse the index.

# %%
df['entity_before'] = add_col(df)
df = df.iloc[::-1]
df['entity_after'] = add_col(df)
df = df.iloc[::-1]

# %% [markdown]
# ## <span style="text-decoration : underline">Data base analysis<span>

# %% [markdown]
# Wordcloud is a very basic data visualization in nlp, and I should make a wordcloud that links the word between each others.

# %%
re.sub(' +',' ','The     quick brown    fox')
# Out:
# 'The quick brown fox'

# %%
fig, ax = plt.subplots(figsize=(12,10))
wordcloud = WordCloud(
                          stopwords= [],
                          background_color='white',
                          width=1200,
                          height=1000
                         ).generate(re.sub(' +',' ',sum_text(df.text)))   #remove multiple spaces in the strinf

plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Here we can guess that the "word" is a wrong stop word for the GetWeather data base.<br>
# In SearchScreeningEvent, the range of size of the words is small, we can guess the error will be bigger than for the others type of query.

# %% [markdown]
# ## <span style="text-decoration : underline">Probability model<span> <br><br>
#
# >
# Giving a $query = (word_1, word_2, ..., word_n)\text{ , } word_i \in \Omega_{word}$ and <br><br>$\Omega_{entity}$ the space of all possible entities for a given type of query.
# >
# Let : $$ word,query \mapsto meaning(word,query)$$ <br><br>be the function that give the entity of the word in the query.
# The problem is to find :<br><br> $$entity = (meaning(word_i , query))_{i \in [1,n]}$$ which is a probabilitical function.<br><br>
# Let's take a $i$ that is not the first neather the last word, I suppose that :<br><br> $$ \mathbb{P}[meaning(word_i,query) = entity_j |query] =  \mathbb{P}[meaning(word_i,query) = entity_j | entity_{i-1},word_{i},entity_{i+1}]$$<br>
# >
# In other words, I assume that the entity of a word in a query depends on itself but also on the entities of the word before and after him.
# Then I calculate the table in which each row represents a word found in the training data base whom columns are a word : <br><br>$$ \forall word_{i} \in \Omega_i  \text{,  }\mathbb{P}[meaning(word_i,query) = entity_j |word_h] $$ <br>$$\forall h \in [i-1,i+1], \forall entity_j \in  \Omega_{entity}$$
#
# >Because I assume that : $$\mathbb{P}[meaning(word_i,query) = entity_j | entity_{i-1},word_{i},entity_{i+1}]$$ has a linear relation with the above proababilities ie :  $$\exists \text{ }(\alpha_{i-1},\alpha_i,\alpha_{i+1}) \in \mathbb{R} ^3,$$ such as :
# $$ \mathbb{P}[meaning(word_i,query) = entity_j | entity_{i-1},word_{i},entity_{i+1}] = $$
# $$\sum_{h = i-1}^{i+1}{ \alpha_h \times \mathbb{P}[meaning(word_i,query)} = entity_j |word_h] $$
#
# >I wheight the probability in the linear relation by the number of occurence  of $word_h$ in the test-base.<br><br>
# Finally, I choose $entity_j$ that maximises the linear relation.

# %%
proba = df.groupby('text').apply(lambda x : pd.Series({
    **{'occurence_number': len(x)},
    
    **{'number_'+entity+'_before' : sum(x.entity_before == entity)/len(x) for entity in all_queries_entity },
                                                                                                          
    **{'number_'+entity+'_after' : sum(x.entity_after == entity)/len(x)  for entity in all_queries_entity  },
                                                                                                                 
    **{'number_'+entity : sum(x.entity == entity)/len(x) for entity in all_queries_entity },
                                                    }
                                                    )).reset_index()

# %% [markdown]
# $\text{text_to_proba}$ is a function that give a dictionary of probability, whose keys are all entity in $\Omega_{entity}$.

# %%
which_list = {'before': '_before' ,'after': '_after', 'itself' : ''}
def text_to_proba(text, which):
    
    proba_dict = { entity : [proba[proba.text == text]['number_'+entity+which_list[which]].iloc[0]  ,  int(proba[proba.text == text]['occurence_number'].iloc[0])] if len(proba[proba.text == text]) > 0 else [0,0] for entity in all_queries_entity }

    return(proba_dict )

# %% [markdown]
# $\text{multiply}$ is a function that a wheighted addition of the probabilities of the 3 dictionnaries. <br>
# Parameters of the wheighted addition are : $$(\alpha,\beta,\gamma)$$<br>

# %%
def multiply(before,itself,after,alpha,beta,gamma):
    new_dic = {}
    list_keys = np.unique(list(before.keys()) + list(itself.keys()) + list(after.keys()))
    
    if before == {}:
        before = {clef : [0,0] for clef in before.keys()}
        
    if itself == {}:
        itself = {clef : [0,0] for clef in before.keys()}
        
    if after == {}:
        after = {clef : [0,0] for clef in before.keys()}
        
    for key in before.keys():
        sum_occurence = before[key][1] + itself[key][1] + after[key][1]
         
        if sum_occurence == 0: #I don't want to divide by zero line 22
            sum_occurence = 1
            
        new_dic[key] = (alpha * before[key][0] * before[key][1]  + beta*itself[key][0]*itself[key][1] + gamma*after[key][0]*after[key][1])/sum_occurence

    if list(max_value(itself).values())[0] >0.90:
        new_dic = max_value(itself)
        
    return(new_dic)

# %% [markdown]
# From a probability dictionnary, $\text{max_value}$  returns a dictionnary with the max value of the dictionnary and the key associated

# %%
def max_value(dico):
    max_value = 0
    max_key = 0
    for key,value in dico.items():
        if value[0] > max_value:
            max_value = value[0]
            max_key = key
    return({max_key : max_value})

# %% [markdown]
# $\text{key_max_value}$ returns, given a dictionnary of probabilities, argmax of the keys

# %%
def key_max_value(dico):
    max_value = 0
    max_key = ''
    for key, value in dico.items():
        if value > max_value:
            max_key = key
            max_value = value
    return(max_key)

# %% [markdown]
# Given a query, $\text{word_to_test}$ returns the entity of each words of the query, by taking the key of the max value in the probability dictionnary.

# %%
def word_to_test_to_demo(query):
    word_tokens = query.split(' ')
    word_tokens = [word_token if word_token not in dico_stop_words[type_of_query] else 'None' for word_token in word_tokens]
   
    dict_output = {}
    for index,word in enumerate(word_tokens):
        if index == 0:
            output = key_max_value(  multiply(text_to_proba(word_tokens[index+1],'before'),text_to_proba(word,'itself'),{},alpha,beta,gamma))
        if index == len(word_tokens)-1:
            output = key_max_value(multiply( text_to_proba(word_tokens[index-1],'before')  ,text_to_proba(word,'itself'), {},alpha,beta,gamma ))
        elif (index >0) & (index < len(word_tokens)-1) :
            output = key_max_value(multiply(text_to_proba(word_tokens[index+1],'before'),text_to_proba(word,'itself'),text_to_proba(word_tokens[index-1],'after'),alpha,beta,gamma))

        dict_output[word] = output
   
    to_return = [{word : dict_output[word]} if word in dict_output.keys() else {word : 'None'} for word in query.split(' ')]

    return(to_return)

# %%
def word_to_test(query):
    word_tokens = query
    vecteur = []
    vecteur_word = []
    
    for index,word in enumerate(word_tokens):
        if index == 0:
            output = key_max_value(  multiply(text_to_proba(word_tokens[index+1],'before'),text_to_proba(word,'itself'),{},alpha,beta,gamma))
        if index == len(word_tokens)-1:
            output = key_max_value(multiply( text_to_proba(word_tokens[index-1],'before')  ,text_to_proba(word,'itself'), {},alpha,beta,gamma ))
        elif (index >0) & (index < len(word_tokens)-1) :
            output = key_max_value(multiply(text_to_proba(word_tokens[index+1],'before'),text_to_proba(word,'itself'),text_to_proba(word_tokens[index-1],'after'),alpha,beta,gamma))
        vecteur_word.append(word)    
        vecteur.append(output)
        
    return([vecteur_word,vecteur])

# %% [markdown]
# Given the test data base and the wheighted parameters, $\text{df_predict_bis}$ returns the data frame with an extra prediction entity column.

# %%
def df_predict_bis(df_test,alpha,beta,gamma):
    entity_test = []
    queries_df = df_test.groupby('query_id')

    for query_id, group in queries_df:
        entity_test += word_to_test(list(group.text))[1]

    df_test['entity_test'] = entity_test
    df_test['prediction'] = df_test.apply(lambda row : row.entity == row.entity_test,axis = 1)

    return(df_test)

# %% [markdown]
# $\text{df_predict}$ returns the metrics performance of the algorithm

# %%
def df_predict(df_test,alpha,beta,gamma):
    entity_test = []
    queries_df = df_test.groupby('query_id')

    for query_id, group in queries_df:
        entity_test += word_to_test(list(group.text))[1]

    df_test['entity_test'] = entity_test
    df_test['prediction'] = df_test.apply(lambda row : row.entity == row.entity_test,axis = 1)
    grouped = df_test.groupby('query_id').apply(lambda x : 1 if sum(x.prediction)/len(x) ==1 else 0).reset_index(name = 'number')
    wrong_entity_rate = sum(grouped.number)/len(grouped)
    wrong_query_rate = sum(df_test.prediction)/len(df_test)
    
    vanity_metric = df_test.groupby('query_id').apply(lambda x : pd.Series({
    'query_type' : list(x[x.entity != 'None'].entity.unique()) ,
    'query_type_test' : list(x[x.entity_test != 'None'].entity_test.unique()) ,
    'query' : sum_text(x.text)
                                } )).reset_index()
    vanity_metric['prediction'] = vanity_metric.apply(lambda row : row.query_type == row.query_type_test , axis =1 )
    vanity_metric = sum(vanity_metric.prediction)/len(vanity_metric)

    return([wrong_entity_rate,wrong_query_rate,vanity_metric])

# %% [markdown]
# ## <span style="text-decoration : underline">Error analysis<span>

# %% [markdown]
# The natural performance metric can be the percentage of query that is full right (every single word of the query has the right entity), I name its the entity metric. <br>
# But it hides a lot of information, I  add another metric (the query metric) wich is the percentage of right entity in the data base of all query merged.<br>
# Then if there is one entity mistake in each queries, entity_metric is 0 where as the query metric gives something close to 1 with a big data base.<br>
# The last metric I chose is the vanity metricfor a given query : 1 if all the entity of the query = prediction(all the entity of the query).

# %%
alpha =1
beta =2
gamma = 0.2
    
temp = df_predict(df_test,alpha,beta,gamma)
entity_metric = temp[0]
query_metric = temp[1]
vanity_metric = temp[2]

# %%
print('For the type of query '+type_of_query+" and for alpha, beta, gamma like above, the algorithm gets the following results :")
print('')
print('Entity metric = '+str(round(entity_metric,2)))
print('Query metric = '+str(round(query_metric ,2)))
print('Vanity metric = '+str(round(vanity_metric,2)))
# Out:
# For the type of query AddToPlaylist and for alpha, beta, gamma like above, the algorithm gets the following results :
#
# Entity metric = 0.35
# Query metric = 0.84
# Vanity metric = 0.45

# %% [markdown]
# ## <span style="text-decoration : underline">Conclusion<span>

# %% [markdown]
# The algorithm performs very good on query where every entities is a single word like :

# %%
word_to_test_to_demo("I'd like to add Californication to the rock playlist")
# Out:
# [{"I'd": 'None'},
#  {'like': 'None'},
#  {'to': 'None'},
#  {'add': 'None'},
#  {'Californication': 'music_item'},
#  {'to': 'None'},
#  {'the': 'None'},
#  {'rock': 'playlist'},
#  {'playlist': 'None'}]

# %% [markdown]
# But fails when the entities are more than 3 words :

# %%
 word_to_test_to_demo("please can you add Also sprach Zarathustra to my cult movie soundtrack playlist")
# Out:
# [{'please': 'None'},
#  {'can': 'None'},
#  {'you': 'None'},
#  {'add': 'None'},
#  {'Also': 'music_item'},
#  {'sprach': ''},
#  {'Zarathoustra': 'music_item'},
#  {'to': 'None'},
#  {'my': 'playlist_owner'},
#  {'cult': 'playlist'},
#  {'movie': 'None'},
#  {'soundtrack': 'playlist'},
#  {'playlist': 'None'}]

# %% [markdown]
# The way to fix this kind of issue could be to calculate the probability of the output and compare with the probability of alternative outputs such as :

# %% [markdown]
# ```python
# [{'please': 'None'},
# {'can': 'None'},
#  {'you': 'None'},
#  {'add': 'None'},
#  {'Also': 'music_item'},
#  {'sprach': 'music_item'},
#  {'Zarathustra': 'music_item'},
#  {'to': 'None'},
#  {'my': 'playlist_owner'},
#  {'cult': 'playlist'},
#  {'movie': 'playlist'},
#  {'songs': 'playlist'},
#  {'playlist': 'None'}] ```

# %% [markdown]
# Or make the entity of a word depends on words further than one before and one after. In the previous query, for the word 'sprach', the algorithm would see 'add' two words before and 'to' two words after and conclude with 'music_item'.

# %% [markdown]
# >Some ideas to increase the performance :
# - Another way to increase the performance would have been to boost the parameters alpha, beta, gamma conditionally to the given word.
#  The easiest way is to perform a linear regression of the probabilities in the Probabilities model part.
# - Boost the parameters alpha, beta conditionally with the type_of_query.<br>
#  In order to make the best boosting of the parameters, I would have merge the training base and test base and make cross-validations by    randomly choosing the test base and the training base. <br>It avoids over-fitting on the test base, and makes a more robust algorithm to change of data
# - Change the number words in the query, <br>'Book a vegan restaurant at nine fifty in the afternoon' will give 'Book a vegan restaurant at 9 50 in the afternoon.' <br>Then add a regex that identifies number in the queries,
# - I noticed spelling mistakes in the data base such as 'plylist' and this remains to be fixed. But it could be very time costful to check for spelling mistake in the whole data base.
# - Make an algorithm that first identify the type of the query by looking at the word in the query and comparing them to the data base of all queries merged and then deal with the query as done here.
